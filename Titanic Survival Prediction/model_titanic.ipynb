# %%
import pandas as pd

# %%
df = pd.read_csv("titanic_survival_ml_ready_2500_rows.csv")

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  Sex   Age  AgeGroup  SibSp  Parch  \
# 0            1         0       2    1  21.6         2      1      0
# 1            2         1       3    1   0.5         0      0      0
# 2            3         0       3    0  24.2         2      1      1
# 3            4         0       3    1  42.8         2      0      0
# 4            5         0       1    0  37.5         2      0      0
#
#    FamilySize  IsAlone   Fare  FarePerPerson  Embarked
# 0           2        0  13.35           6.68         0
# 1           1        1  18.38          18.38         2
# 2           3        0  15.03           5.01         0
# 3           1        1  21.70          21.70         2
# 4           1        1  91.02          91.02         2
